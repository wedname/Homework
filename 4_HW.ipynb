# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

# %%
df = pd.read_csv("Datasets/cars_imputed.csv")

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses   wheel-base   length   width  \
# 0             0        3.0              115.0         88.6    168.8    64.1
# 1             1        3.0              115.0         88.6    168.8    64.1
# 2             2        1.0              115.0         94.5    171.2    65.5
# 3             3        2.0              164.0         99.8    176.6    66.2
# 4             4        2.0              164.0         99.4    176.6    66.4
# ..          ...        ...                ...          ...      ...     ...
# 200         200       -1.0               95.0        109.1    188.8    68.9
# 201         201       -1.0               95.0        109.1    188.8    68.8
# 202         202       -1.0               95.0        109.1    188.8    68.9
# 203         203       -1.0               95.0        109.1    188.8    68.9
# 204         204       -1.0               95.0        109.1    188.8    68.9
#
#       height   curb-weight   engine-size   compression-ratio  ...  \
# 0       48.8        2548.0         130.0                 9.0  ...
# 1       48.8        2548.0         130.0                 9.0  ...
# 2       52.4        2823.0         152.0                 9.0  ...
# 3       54.3        2337.0         109.0                10.0  ...
# 4       54.3        2824.0         136.0                 8.0  ...
# ..       ...           ...           ...                 ...  ...
# 200     55.5        2952.0         141.0                 9.5  ...
# 201     55.5        3049.0         141.0                 8.7  ...
# 202     55.5        3012.0         173.0                 8.8  ...
# 203     55.5        3217.0         145.0                23.0  ...
# 204     55.5        3062.0         141.0                 9.5  ...
#
#      num-of-doors   body-style  drive-wheels  engine-location   engine-type  \
# 0             two  convertible           rwd            front          dohc
# 1             two  convertible           rwd            front          dohc
# 2             two    hatchback           rwd            front          ohcv
# 3            four        sedan           fwd            front           ohc
# 4            four        sedan           4wd            front           ohc
# ..            ...          ...           ...              ...           ...
# 200          four        sedan           rwd            front           ohc
# 201          four        sedan           rwd            front           ohc
# 202          four        sedan           rwd            front          ohcv
# 203          four        sedan           rwd            front           ohc
# 204          four        sedan           rwd            front           ohc
#
#      num-of-cylinders  fuel-system  bore  stroke   price.1
# 0                four         mpfi  3.47    2.68     13495
# 1                four         mpfi  3.47    2.68     16500
# 2                 six         mpfi  2.68    3.47     16500
# 3                four         mpfi  3.19    3.40     13950
# 4                five         mpfi  3.19    3.40     17450
# ..                ...          ...   ...     ...       ...
# 200              four         mpfi  3.78    3.15     16845
# 201              four         mpfi  3.78    3.15     19045
# 202               six         mpfi  3.58    2.87     21485
# 203               six          idi  3.01    3.40     22470
# 204              four         mpfi  3.78    3.15     22625
#
# [205 rows x 28 columns]

# %%
df = df.drop(['Unnamed: 0', '  price.1'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symboling           205 non-null    float64
#  1   normalized-losses   205 non-null    float64
#  2    wheel-base         205 non-null    float64
#  3    length             205 non-null    float64
#  4    width              205 non-null    float64
#  5    height             205 non-null    float64
#  6    curb-weight        205 non-null    float64
#  7    engine-size        205 non-null    float64
#  8    compression-ratio  205 non-null    float64
#  9    horsepower         205 non-null    float64
#  10   peak-rpm           205 non-null    float64
#  11   city-mpg           205 non-null    float64
#  12   highway-mpg        205 non-null    float64
#  13    price             205 non-null    float64
#  14  make                205 non-null    object
#  15  fuel-type           205 non-null    object
#  16  aspiration          205 non-null    object
#  17  num-of-doors        205 non-null    object
#  18  body-style          205 non-null    object
#  19  drive-wheels        205 non-null    object
#  20  engine-location     205 non-null    object
#  21   engine-type        205 non-null    object
#  22   num-of-cylinders   205 non-null    object
#  23   fuel-system        205 non-null    object
#  24   bore               205 non-null    float64
#  25   stroke             205 non-null    float64
# dtypes: float64(16), object(10)
# memory usage: 41.8+ KB

# %%
from pandas.plotting import scatter_matrix

num_columns = ['symboling', 'normalized-losses', ' wheel-base', ' length',
               ' width', ' height', ' curb-weight', ' engine-size', ' compression-ratio',
               ' horsepower', ' peak-rpm', ' city-mpg', ' highway-mpg', ' bore', ' stroke', '  price']

scatter_matrix(df[num_columns], figsize=(15, 15))
# Out:
# array([[<AxesSubplot:xlabel='symboling', ylabel='symboling'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' length', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' width', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' height', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' bore', ylabel='symboling'>,
#         <AxesSubplot:xlabel=' stroke', ylabel='symboling'>,
#         <AxesSubplot:xlabel='  price', ylabel='symboling'>],
#        [<AxesSubplot:xlabel='symboling', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' length', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' width', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' height', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' bore', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel=' stroke', ylabel='normalized-losses'>,
#         <AxesSubplot:xlabel='  price', ylabel='normalized-losses'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' length', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' width', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' height', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' wheel-base'>,
#         <AxesSubplot:xlabel='  price', ylabel=' wheel-base'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' length'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' length'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' length'>,
#         <AxesSubplot:xlabel=' length', ylabel=' length'>,
#         <AxesSubplot:xlabel=' width', ylabel=' length'>,
#         <AxesSubplot:xlabel=' height', ylabel=' length'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' length'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' length'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' length'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' length'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' length'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' length'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' length'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' length'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' length'>,
#         <AxesSubplot:xlabel='  price', ylabel=' length'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' width'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' width'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' width'>,
#         <AxesSubplot:xlabel=' length', ylabel=' width'>,
#         <AxesSubplot:xlabel=' width', ylabel=' width'>,
#         <AxesSubplot:xlabel=' height', ylabel=' width'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' width'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' width'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' width'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' width'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' width'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' width'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' width'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' width'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' width'>,
#         <AxesSubplot:xlabel='  price', ylabel=' width'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' height'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' height'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' height'>,
#         <AxesSubplot:xlabel=' length', ylabel=' height'>,
#         <AxesSubplot:xlabel=' width', ylabel=' height'>,
#         <AxesSubplot:xlabel=' height', ylabel=' height'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' height'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' height'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' height'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' height'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' height'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' height'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' height'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' height'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' height'>,
#         <AxesSubplot:xlabel='  price', ylabel=' height'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' length', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' width', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' height', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' curb-weight'>,
#         <AxesSubplot:xlabel='  price', ylabel=' curb-weight'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' length', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' width', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' height', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' engine-size'>,
#         <AxesSubplot:xlabel='  price', ylabel=' engine-size'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' length', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' width', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' height', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' compression-ratio'>,
#         <AxesSubplot:xlabel='  price', ylabel=' compression-ratio'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' length', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' width', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' height', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' horsepower'>,
#         <AxesSubplot:xlabel='  price', ylabel=' horsepower'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' length', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' width', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' height', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' peak-rpm'>,
#         <AxesSubplot:xlabel='  price', ylabel=' peak-rpm'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' length', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' width', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' height', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' city-mpg'>,
#         <AxesSubplot:xlabel='  price', ylabel=' city-mpg'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' length', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' width', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' height', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' highway-mpg'>,
#         <AxesSubplot:xlabel='  price', ylabel=' highway-mpg'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' bore'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' length', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' width', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' height', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' bore'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' bore'>,
#         <AxesSubplot:xlabel='  price', ylabel=' bore'>],
#        [<AxesSubplot:xlabel='symboling', ylabel=' stroke'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' length', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' width', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' height', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' bore', ylabel=' stroke'>,
#         <AxesSubplot:xlabel=' stroke', ylabel=' stroke'>,
#         <AxesSubplot:xlabel='  price', ylabel=' stroke'>],
#        [<AxesSubplot:xlabel='symboling', ylabel='  price'>,
#         <AxesSubplot:xlabel='normalized-losses', ylabel='  price'>,
#         <AxesSubplot:xlabel=' wheel-base', ylabel='  price'>,
#         <AxesSubplot:xlabel=' length', ylabel='  price'>,
#         <AxesSubplot:xlabel=' width', ylabel='  price'>,
#         <AxesSubplot:xlabel=' height', ylabel='  price'>,
#         <AxesSubplot:xlabel=' curb-weight', ylabel='  price'>,
#         <AxesSubplot:xlabel=' engine-size', ylabel='  price'>,
#         <AxesSubplot:xlabel=' compression-ratio', ylabel='  price'>,
#         <AxesSubplot:xlabel=' horsepower', ylabel='  price'>,
#         <AxesSubplot:xlabel=' peak-rpm', ylabel='  price'>,
#         <AxesSubplot:xlabel=' city-mpg', ylabel='  price'>,
#         <AxesSubplot:xlabel=' highway-mpg', ylabel='  price'>,
#         <AxesSubplot:xlabel=' bore', ylabel='  price'>,
#         <AxesSubplot:xlabel=' stroke', ylabel='  price'>,
#         <AxesSubplot:xlabel='  price', ylabel='  price'>]], dtype=object)

# %%
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
df_num = df[num_columns]
df_num
# Out:
#      symboling  normalized-losses   wheel-base   length   width   height  \
# 0          3.0              115.0         88.6    168.8    64.1     48.8
# 1          3.0              115.0         88.6    168.8    64.1     48.8
# 2          1.0              115.0         94.5    171.2    65.5     52.4
# 3          2.0              164.0         99.8    176.6    66.2     54.3
# 4          2.0              164.0         99.4    176.6    66.4     54.3
# ..         ...                ...          ...      ...     ...      ...
# 200       -1.0               95.0        109.1    188.8    68.9     55.5
# 201       -1.0               95.0        109.1    188.8    68.8     55.5
# 202       -1.0               95.0        109.1    188.8    68.9     55.5
# 203       -1.0               95.0        109.1    188.8    68.9     55.5
# 204       -1.0               95.0        109.1    188.8    68.9     55.5
#
#       curb-weight   engine-size   compression-ratio   horsepower   peak-rpm  \
# 0          2548.0         130.0                 9.0        111.0     5000.0
# 1          2548.0         130.0                 9.0        111.0     5000.0
# 2          2823.0         152.0                 9.0        154.0     5000.0
# 3          2337.0         109.0                10.0        102.0     5500.0
# 4          2824.0         136.0                 8.0        115.0     5500.0
# ..            ...           ...                 ...          ...        ...
# 200        2952.0         141.0                 9.5        114.0     5400.0
# 201        3049.0         141.0                 8.7        160.0     5300.0
# 202        3012.0         173.0                 8.8        134.0     5500.0
# 203        3217.0         145.0                23.0        106.0     4800.0
# 204        3062.0         141.0                 9.5        114.0     5400.0
#
#       city-mpg   highway-mpg   bore   stroke    price
# 0         21.0          27.0   3.47     2.68  13495.0
# 1         21.0          27.0   3.47     2.68  16500.0
# 2         19.0          26.0   2.68     3.47  16500.0
# 3         24.0          30.0   3.19     3.40  13950.0
# 4         18.0          22.0   3.19     3.40  17450.0
# ..         ...           ...    ...      ...      ...
# 200       23.0          28.0   3.78     3.15  16845.0
# 201       19.0          25.0   3.78     3.15  19045.0
# 202       18.0          23.0   3.58     2.87  21485.0
# 203       26.0          27.0   3.01     3.40  22470.0
# 204       19.0          25.0   3.78     3.15  22625.0
#
# [205 rows x 16 columns]

# %%
from sklearn.preprocessing import (MinMaxScaler, PolynomialFeatures)


scale_columns = ['normalized-losses', ' height', ' curb-weight', ' compression-ratio',' peak-rpm']
minmax_scaler = MinMaxScaler()
minmax_scaler.fit(df_num[scale_columns])
df_num[scale_columns] = minmax_scaler.transform(df_num[scale_columns])

poly_columns = ['normalized-losses', ' height', ' curb-weight', ' compression-ratio',' peak-rpm']
poly_transform = PolynomialFeatures(3, interaction_only=True)
poly_features = poly_transform.fit_transform(df_num[poly_columns])
for index in range(poly_features.shape[1]):
    df_num[f"Poly_column_{index}"] = poly_features[:, index]
df_num.columns
# Out:
# F:\Curs_Step\Python\Project\AI\Homework\venv\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# C:\Users\vvygo\AppData\Local\Temp/ipykernel_7768/4202983630.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num[f"Poly_column_{index}"] = poly_features[:, index]
# Index(['symboling', 'normalized-losses', ' wheel-base', ' length', ' width',
#        ' height', ' curb-weight', ' engine-size', ' compression-ratio',
#        ' horsepower', ' peak-rpm', ' city-mpg', ' highway-mpg', ' bore',
#        ' stroke', '  price', 'Poly_column_0', 'Poly_column_1', 'Poly_column_2',
#        'Poly_column_3', 'Poly_column_4', 'Poly_column_5', 'Poly_column_6',
#        'Poly_column_7', 'Poly_column_8', 'Poly_column_9', 'Poly_column_10',
#        'Poly_column_11', 'Poly_column_12', 'Poly_column_13', 'Poly_column_14',
#        'Poly_column_15', 'Poly_column_16', 'Poly_column_17', 'Poly_column_18',
#        'Poly_column_19', 'Poly_column_20', 'Poly_column_21', 'Poly_column_22',
#        'Poly_column_23', 'Poly_column_24', 'Poly_column_25'],
#       dtype='object')

# %%
df_num
# Out:
#      symboling  normalized-losses   wheel-base   length   width    height  \
# 0          3.0           0.261780         88.6    168.8    64.1  0.083333
# 1          3.0           0.261780         88.6    168.8    64.1  0.083333
# 2          1.0           0.261780         94.5    171.2    65.5  0.383333
# 3          2.0           0.518325         99.8    176.6    66.2  0.541667
# 4          2.0           0.518325         99.4    176.6    66.4  0.541667
# ..         ...                ...          ...      ...     ...       ...
# 200       -1.0           0.157068        109.1    188.8    68.9  0.641667
# 201       -1.0           0.157068        109.1    188.8    68.8  0.641667
# 202       -1.0           0.157068        109.1    188.8    68.9  0.641667
# 203       -1.0           0.157068        109.1    188.8    68.9  0.641667
# 204       -1.0           0.157068        109.1    188.8    68.9  0.641667
#
#       curb-weight   engine-size   compression-ratio   horsepower  ...  \
# 0        0.411171         130.0             0.12500        111.0  ...
# 1        0.411171         130.0             0.12500        111.0  ...
# 2        0.517843         152.0             0.12500        154.0  ...
# 3        0.329325         109.0             0.18750        102.0  ...
# 4        0.518231         136.0             0.06250        115.0  ...
# ..            ...           ...                 ...          ...  ...
# 200      0.567882         141.0             0.15625        114.0  ...
# 201      0.605508         141.0             0.10625        160.0  ...
# 202      0.591156         173.0             0.11250        134.0  ...
# 203      0.670675         145.0             1.00000        106.0  ...
# 204      0.610551         141.0             0.15625        114.0  ...
#
#      Poly_column_16  Poly_column_17  Poly_column_18  Poly_column_19  \
# 0          0.008970        0.002727        0.007568        0.013455
# 1          0.008970        0.002727        0.007568        0.013455
# 2          0.051965        0.012544        0.034815        0.016945
# 3          0.092461        0.052642        0.154704        0.032006
# 4          0.145498        0.017547        0.154704        0.016788
# ..              ...             ...             ...             ...
# 200        0.057234        0.015748        0.051421        0.013937
# 201        0.061026        0.010708        0.047307        0.010105
# 202        0.059580        0.011338        0.055535        0.010446
# 203        0.067594        0.100785        0.026739        0.105342
# 204        0.061535        0.015748        0.051421        0.014984
#
#      Poly_column_20  Poly_column_21  Poly_column_22  Poly_column_23  \
# 0          0.037343        0.011353        0.004283        0.011888
# 1          0.037343        0.011353        0.004283        0.011888
# 2          0.047031        0.011353        0.024813        0.068870
# 3          0.094058        0.053551        0.033447        0.098293
# 4          0.148011        0.017850        0.017544        0.154676
# ..              ...             ...             ...             ...
# 200        0.045508        0.012521        0.056936        0.185914
# 201        0.044642        0.007833        0.041282        0.182373
# 202        0.051163        0.009737        0.042674        0.209016
# 203        0.027948        0.041671        0.430350        0.114174
# 204        0.048928        0.012521        0.061214        0.199883
#
#      Poly_column_24  Poly_column_25
# 0          0.003614        0.017831
# 1          0.003614        0.017831
# 2          0.016624        0.022457
# 3          0.055963        0.034025
# 4          0.018654        0.017847
# ..              ...             ...
# 200        0.051153        0.045271
# 201        0.032001        0.030198
# 202        0.039777        0.036646
# 203        0.170238        0.177934
# 204        0.051153        0.048673
#
# [205 rows x 42 columns]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df_num, test_size=0.35, random_state=42)
train_set.head(5)
# Out:
#      symboling  normalized-losses   wheel-base   length   width    height  \
# 140        2.0           0.094241         93.3    157.3    63.8  0.658333
# 51         1.0           0.204188         93.1    159.1    64.2  0.525000
# 113        0.0           0.261780        114.2    198.9    68.4  0.741667
# 166        1.0           0.539267         94.5    168.7    64.0  0.400000
# 41         0.0           0.104712         96.5    175.4    65.2  0.525000
#
#       curb-weight   engine-size   compression-ratio   horsepower  ...  \
# 140      0.291699         108.0             0.10625         73.0  ...
# 51       0.159814          91.0             0.12500         68.0  ...
# 113      0.697052         120.0             0.08750         95.0  ...
# 166      0.314973          98.0             0.15000        112.0  ...
# 41       0.378976         110.0             0.12500        101.0  ...
#
#      Poly_column_16  Poly_column_17  Poly_column_18  Poly_column_19  \
# 140        0.018098        0.006592        0.006331        0.002921
# 51         0.017132        0.013400        0.037191        0.004079
# 113        0.135335        0.016988        0.067359        0.015967
# 166        0.067942        0.032356        0.215707        0.025478
# 41         0.020834        0.006872        0.037023        0.004960
#
#      Poly_column_20  Poly_column_21  Poly_column_22  Poly_column_23  \
# 140        0.002805        0.001022        0.020404        0.019595
# 51         0.011321        0.008855        0.010488        0.029109
# 113        0.063307        0.007947        0.045236        0.179360
# 166        0.169854        0.080890        0.018898        0.125989
# 41         0.026726        0.008815        0.024870        0.133995
#
#      Poly_column_24  Poly_column_25
# 140        0.007138        0.003163
# 51         0.022768        0.006931
# 113        0.022515        0.021161
# 166        0.060000        0.047246
# 41         0.044196        0.031904
#
# [5 rows x 42 columns]

# %%
Xs = ['normalized-losses', ' wheel-base', ' length', ' width', ' height',
       ' curb-weight', ' engine-size', ' compression-ratio', ' horsepower',
       ' peak-rpm', ' city-mpg', ' highway-mpg', ' bore', ' stroke', '  price']
Ys = ['symboling']

# %%
train_Xs = train_set[Xs]
train_Ys = train_set[Ys]

test_Xs = test_set[Xs]
test_Ys = test_set[Ys]

# %%
def MAE(Ys_real, Ys_predict):
    Losses = np.abs(Ys_real - Ys_predict)
    m = len(Ys_real)
    cost_result = 1 / m * np.sum(Losses)
    return cost_result

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

model = LinearRegression()
model.fit(train_Xs, train_Ys)
predictions = model.predict(train_Xs)
print("MAE train:", MAE(train_Ys, predictions))
predictions = model.predict(test_Xs)
print("MAE test:", MAE(test_Ys, predictions))
# Out:
# MAE train: symboling    0.656571
# dtype: float64
# MAE test: symboling    0.760814
# dtype: float64

# %%
model = Lasso(alpha=10e-3)
model.fit(train_Xs, train_Ys)
predictions_Lasso = model.predict(train_Xs)
predictions_Lasso = predictions_Lasso.reshape(-1, 1)
print("MAE Lasso Train:", MAE(train_Ys, predictions_Lasso))

predictions_Lasso = model.predict(test_Xs)
predictions_Lasso = predictions_Lasso.reshape(-1, 1)
print("MAE Lasso Test:", MAE(test_Ys, predictions_Lasso))
# Out:
# MAE Lasso Train: symboling    0.672123
# dtype: float64
# MAE Lasso Test: symboling    0.759703
# dtype: float64

# %%
model = Ridge(alpha=10e-3)
model.fit(train_Xs, train_Ys)
predictions_Ridge = model.predict(train_Xs)
predictions_Ridge = predictions_Ridge.reshape(-1, 1)
print("MAE Ridge Train:", MAE(train_Ys, predictions_Ridge))

predictions_Ridge = model.predict(test_Xs)
predictions_Ridge = predictions_Ridge.reshape(-1, 1)
print("MAE Ridge Test:", MAE(test_Ys, predictions_Ridge))
# Out:
# MAE Ridge Train: symboling    0.656594
# dtype: float64
# MAE Ridge Test: symboling    0.761009
# dtype: float64
