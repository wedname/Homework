# %%
#Задания 1-2

# %%
#!pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
np.random.seed(42)

# %%
df = pd.read_csv("Datasets/imports-85.data.csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location   wheel-base  ...  \
# 0            two  convertible          rwd           front         88.6  ...
# 1            two  convertible          rwd           front         88.6  ...
# 2            two    hatchback          rwd           front         94.5  ...
# 3           four        sedan          fwd           front         99.8  ...
# 4           four        sedan          4wd           front         99.4  ...
# ..           ...          ...          ...             ...          ...  ...
# 200         four        sedan          rwd           front        109.1  ...
# 201         four        sedan          rwd           front        109.1  ...
# 202         four        sedan          rwd           front        109.1  ...
# 203         four        sedan          rwd           front        109.1  ...
# 204         four        sedan          rwd           front        109.1  ...
#
#       fuel-system   bore   stroke   compression-ratio  horsepower  peak-rpm  \
# 0            mpfi   3.47     2.68                 9.0         111      5000
# 1            mpfi   3.47     2.68                 9.0         111      5000
# 2            mpfi   2.68     3.47                 9.0         154      5000
# 3            mpfi   3.19     3.40                10.0         102      5500
# 4            mpfi   3.19     3.40                 8.0         115      5500
# ..            ...    ...      ...                 ...         ...       ...
# 200          mpfi   3.78     3.15                 9.5         114      5400
# 201          mpfi   3.78     3.15                 8.7         160      5300
# 202          mpfi   3.58     2.87                 8.8         134      5500
# 203           idi   3.01     3.40                23.0         106      4800
# 204          mpfi   3.78     3.15                 9.5         114      5400
#
#       city-mpg  highway-mpg   price Unnamed: 26
# 0           21           27   13495         NaN
# 1           21           27   16500         NaN
# 2           19           26   16500         NaN
# 3           24           30   13950         NaN
# 4           18           22   17450         NaN
# ..         ...          ...     ...         ...
# 200         23           28   16845         NaN
# 201         19           25   19045         NaN
# 202         18           23   21485         NaN
# 203         26           27   22470         NaN
# 204         19           25   22625         NaN
#
# [205 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symboling           205 non-null    int64
#  1   normalized-losses   205 non-null    object
#  2   make                205 non-null    object
#  3   fuel-type           205 non-null    object
#  4   aspiration          205 non-null    object
#  5   num-of-doors        205 non-null    object
#  6   body-style          205 non-null    object
#  7   drive-wheels        205 non-null    object
#  8   engine-location     205 non-null    object
#  9    wheel-base         205 non-null    float64
#  10   length             205 non-null    float64
#  11   width              205 non-null    float64
#  12   height             205 non-null    float64
#  13   curb-weight        205 non-null    int64
#  14   engine-type        205 non-null    object
#  15   num-of-cylinders   205 non-null    object
#  16   engine-size        205 non-null    int64
#  17   fuel-system        205 non-null    object
#  18   bore               205 non-null    object
#  19   stroke             205 non-null    object
#  20   compression-ratio  205 non-null    float64
#  21   horsepower         205 non-null    object
#  22   peak-rpm           205 non-null    object
#  23   city-mpg           205 non-null    int64
#  24   highway-mpg        205 non-null    int64
#  25    price             205 non-null    object
#  26  Unnamed: 26         0 non-null      float64
# dtypes: float64(6), int64(5), object(16)
# memory usage: 43.4+ KB

# %%
df = df.drop(np.where(df['normalized-losses'] == "?")[0])
df = df.drop(np.where(df[' bore'] == "?")[0])
df = df.drop(np.where(df[' stroke'] == "?")[0])
df = df.drop(np.where(df['num-of-doors'] == "?")[0])

# %%
df
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# 10           2               192    bmw       gas        std          two
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location   wheel-base  ...   fuel-system  \
# 3        sedan          fwd           front         99.8  ...          mpfi
# 4        sedan          4wd           front         99.4  ...          mpfi
# 6        sedan          fwd           front        105.8  ...          mpfi
# 8        sedan          fwd           front        105.8  ...          mpfi
# 10       sedan          rwd           front        101.2  ...          mpfi
# ..         ...          ...             ...          ...  ...           ...
# 200      sedan          rwd           front        109.1  ...          mpfi
# 201      sedan          rwd           front        109.1  ...          mpfi
# 202      sedan          rwd           front        109.1  ...          mpfi
# 203      sedan          rwd           front        109.1  ...           idi
# 204      sedan          rwd           front        109.1  ...          mpfi
#
#       bore   stroke   compression-ratio  horsepower  peak-rpm   city-mpg  \
# 3     3.19     3.40                10.0         102      5500         24
# 4     3.19     3.40                 8.0         115      5500         18
# 6     3.19     3.40                 8.5         110      5500         19
# 8     3.13     3.40                 8.3         140      5500         17
# 10    3.50     2.80                 8.8         101      5800         23
# ..     ...      ...                 ...         ...       ...        ...
# 200   3.78     3.15                 9.5         114      5400         23
# 201   3.78     3.15                 8.7         160      5300         19
# 202   3.58     2.87                 8.8         134      5500         18
# 203   3.01     3.40                23.0         106      4800         26
# 204   3.78     3.15                 9.5         114      5400         19
#
#      highway-mpg   price Unnamed: 26
# 3             30   13950         NaN
# 4             22   17450         NaN
# 6             25   17710         NaN
# 8             20   23875         NaN
# 10            29   16430         NaN
# ..           ...     ...         ...
# 200           28   16845         NaN
# 201           25   19045         NaN
# 202           23   21485         NaN
# 203           27   22470         NaN
# 204           25   22625         NaN
#
# [148 rows x 27 columns]

# %%
df = df.drop(['make', 'fuel-type', 'aspiration',
                'num-of-doors', 'body-style',
                'drive-wheels', 'engine-location',
                ' engine-type', ' num-of-cylinders',
                ' fuel-system', ' bore', ' stroke'], axis='columns')

# %%
df
# Out:
#      symboling normalized-losses   wheel-base   length   width   height  \
# 3            2               164         99.8    176.6    66.2     54.3
# 4            2               164         99.4    176.6    66.4     54.3
# 6            1               158        105.8    192.7    71.4     55.7
# 8            1               158        105.8    192.7    71.4     55.9
# 10           2               192        101.2    176.8    64.8     54.3
# ..         ...               ...          ...      ...     ...      ...
# 200         -1                95        109.1    188.8    68.9     55.5
# 201         -1                95        109.1    188.8    68.8     55.5
# 202         -1                95        109.1    188.8    68.9     55.5
# 203         -1                95        109.1    188.8    68.9     55.5
# 204         -1                95        109.1    188.8    68.9     55.5
#
#       curb-weight   engine-size   compression-ratio  horsepower  peak-rpm  \
# 3            2337           109                10.0         102      5500
# 4            2824           136                 8.0         115      5500
# 6            2844           136                 8.5         110      5500
# 8            3086           131                 8.3         140      5500
# 10           2395           108                 8.8         101      5800
# ..            ...           ...                 ...         ...       ...
# 200          2952           141                 9.5         114      5400
# 201          3049           141                 8.7         160      5300
# 202          3012           173                 8.8         134      5500
# 203          3217           145                23.0         106      4800
# 204          3062           141                 9.5         114      5400
#
#       city-mpg   highway-mpg   price  Unnamed: 26
# 3           24            30   13950          NaN
# 4           18            22   17450          NaN
# 6           19            25   17710          NaN
# 8           17            20   23875          NaN
# 10          23            29   16430          NaN
# ..         ...           ...     ...          ...
# 200         23            28   16845          NaN
# 201         19            25   19045          NaN
# 202         18            23   21485          NaN
# 203         26            27   22470          NaN
# 204         19            25   22625          NaN
#
# [148 rows x 15 columns]

# %%
df.to_csv('Datasets/cars_nums.csv')

# %%
df = pd.read_csv("Datasets/cars_nums.csv")

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 26'], axis=1)

# %%
df
# Out:
#      symboling  normalized-losses   wheel-base   length   width   height  \
# 0            2                164         99.8    176.6    66.2     54.3
# 1            2                164         99.4    176.6    66.4     54.3
# 2            1                158        105.8    192.7    71.4     55.7
# 3            1                158        105.8    192.7    71.4     55.9
# 4            2                192        101.2    176.8    64.8     54.3
# ..         ...                ...          ...      ...     ...      ...
# 143         -1                 95        109.1    188.8    68.9     55.5
# 144         -1                 95        109.1    188.8    68.8     55.5
# 145         -1                 95        109.1    188.8    68.9     55.5
# 146         -1                 95        109.1    188.8    68.9     55.5
# 147         -1                 95        109.1    188.8    68.9     55.5
#
#       curb-weight   engine-size   compression-ratio   horsepower   peak-rpm  \
# 0            2337           109                10.0          102       5500
# 1            2824           136                 8.0          115       5500
# 2            2844           136                 8.5          110       5500
# 3            3086           131                 8.3          140       5500
# 4            2395           108                 8.8          101       5800
# ..            ...           ...                 ...          ...        ...
# 143          2952           141                 9.5          114       5400
# 144          3049           141                 8.7          160       5300
# 145          3012           173                 8.8          134       5500
# 146          3217           145                23.0          106       4800
# 147          3062           141                 9.5          114       5400
#
#       city-mpg   highway-mpg    price
# 0           24            30    13950
# 1           18            22    17450
# 2           19            25    17710
# 3           17            20    23875
# 4           23            29    16430
# ..         ...           ...      ...
# 143         23            28    16845
# 144         19            25    19045
# 145         18            23    21485
# 146         26            27    22470
# 147         19            25    22625
#
# [148 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symboling           148 non-null    int64
#  1   normalized-losses   148 non-null    int64
#  2    wheel-base         148 non-null    float64
#  3    length             148 non-null    float64
#  4    width              148 non-null    float64
#  5    height             148 non-null    float64
#  6    curb-weight        148 non-null    int64
#  7    engine-size        148 non-null    int64
#  8    compression-ratio  148 non-null    float64
#  9    horsepower         148 non-null    int64
#  10   peak-rpm           148 non-null    int64
#  11   city-mpg           148 non-null    int64
#  12   highway-mpg        148 non-null    int64
#  13    price             148 non-null    int64
# dtypes: float64(5), int64(9)
# memory usage: 16.3 KB

# %%
train_set, test_set = train_test_split(df, test_size=0.35, random_state=42)
train_set.head(5)
# Out:
#     symboling  normalized-losses   wheel-base   length   width   height  \
# 40          2                161         93.7    157.3    64.4     50.8
# 60          0                128        100.4    181.7    66.5     55.1
# 24          3                150         95.3    169.0    65.7     49.6
# 25          3                150         95.3    169.0    65.7     49.6
# 23          3                150         95.3    169.0    65.7     49.6
#
#      curb-weight   engine-size   compression-ratio   horsepower   peak-rpm  \
# 40          2004            92                 9.4           68       5500
# 60          3095           181                 9.0          152       5200
# 24          2380            70                 9.4          101       6000
# 25          2385            70                 9.4          101       6000
# 23          2380            70                 9.4          101       6000
#
#      city-mpg   highway-mpg    price
# 40         31            38     6669
# 60         17            22    13499
# 24         17            23    11845
# 25         17            23    13645
# 23         17            23    10945

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', ' wheel-base', ' length', ' width',
#        ' height', ' curb-weight', ' engine-size', ' compression-ratio',
#        ' horsepower', ' peak-rpm', ' city-mpg', ' highway-mpg', '  price'],
#       dtype='object')

# %%
Xs = ['normalized-losses', ' wheel-base', ' length', ' width', ' height',
       ' curb-weight', ' engine-size', ' compression-ratio', ' horsepower',
       ' peak-rpm', ' city-mpg', ' highway-mpg', '  price']
Ys = ['symboling']

# %%
train_Xs = train_set[Xs]
train_Ys = train_set[Ys]

test_Xs = test_set[Xs]
test_Ys = test_set[Ys]

# %%
def MAE(Ys_real, Ys_predict):
    Losses = np.abs(Ys_real - Ys_predict)
    m = len(Ys_real)
    cost_result = 1 / m * np.sum(Losses)
    return cost_result

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(train_Xs, train_Ys)
predictions = model.predict(train_Xs)
print("MAE train:", MAE(train_Ys, predictions))
# Out:
# MAE train: symboling    0.598941
# dtype: float64

# %%
predictions = model.predict(test_Xs)
print("MAE test:", MAE(test_Ys, predictions))
# Out:
# MAE test: symboling    0.69615
# dtype: float64
